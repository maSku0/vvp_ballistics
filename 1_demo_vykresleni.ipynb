# %%
import numpy as np
import matplotlib.pyplot as plt

from classes.projectile import Projectile
from classes.constant import *
from classes.trajectories import *

# %% [markdown]
# Vytvoření projektilu reprezentující celoplášťovou střelu S&B ráže .308 o hmotnosti 147grs a balistickém koeficientu G1 0.489 a SD 0.221

# %%
projectile = Projectile("S&B FMJ 147grs", cal_inch=0.308, m_grs=147, G1=0.489, SD_inch=0.221)

# %% [markdown]
# Vytvoření matice o hodnotách ve sloupích $\displaystyle [x, y, v_x, v_y]$ a vynesení prvních dvou sloupců do grafu

# %%
solution = trajectory(projectile,735)

x = solution[:, 0]
y = solution[:, 1]

plot(x,y,'Ballistic Trajectory with Drag','Horizontal Distance (m)','Vertical Distance (m)',x_limit=(0,400),y_limit=(1,-5))

# %% [markdown]
# Funkce ```printTable``` vytiskne tabulku hodnot pro jednodušší orientaci.
#
# Pomocí argumentů funkce jde ovlivnit výpis. ```compacted``` vybere pouze vybrané hodnoty - podle vzdálenosti $x$ specifikované atributy ```rang``` (maximální vzdálenost) a ```step``` (krok mezi jednotlivými vzdálenostmi)
#
# ```normalise``` společně s povinným argumentem ```cols``` (tuple) zredukuje přes skalární součin dva sloupce ```cols[1]-->cols[0]```

# %%
printTable(solution, ("x","y","v"), compacted=True, step=50, normalise=True, cols=(2,3))
# Out:
# x: 50.0, y: -0.030580234101848812, v: 674.9556032348451
# x: 100.0, y: -0.10511406140922866, v: 629.9282360346074
# x: 150.0, y: -0.24136261797415665, v: 585.3046390752478
# x: 200.0, y: -0.4560099713217302, v: 542.1037982818954
# x: 250.0, y: -0.7665344983576732, v: 501.0175687544773
# x: 300.0, y: -1.1491086152403194, v: 465.72302231884277
# x: 350.0, y: -1.649450248621754, v: 432.2327660635745
# x: 400.0, y: -2.2865167303570337, v: 400.79607231119013
# x: 450.0, y: -3.0802498240730762, v: 371.5288587201727
# x: 500.0, y: -4.05162880838645, v: 344.4494163670123
